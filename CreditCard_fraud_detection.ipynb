# %%
from pandas import read_csv
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = read_csv('/content/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df=df.drop_duplicates()

# %%
df.isna().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
print(df.isnull().sum(axis=1))
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Length: 283726, dtype: int64

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %%
df = df.loc[:,df.columns[df.isnull().sum() / df.shape[0] < 0.9 ]]

# %%
df = df.loc[df.isnull().sum(axis=1) <=(df.shape[1] * 0.5),: ]

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# # X & Y Split

# %%
X = df.drop('Class',axis=1)
Y = df['Class']

# %%
X.shape,Y.shape
# Out:
# ((283726, 30), (283726,))

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3, random_state=7)

# %% [markdown]
# # Normalization

# %%
from sklearn import preprocessing
x = X_train.values #returns a numpy array
std_scaler = preprocessing.StandardScaler()
std_scaler.fit(x)
x_scaled_std = std_scaler.transform(x)
X_train_std = pd.DataFrame(x_scaled_std,columns=X_train.columns)

# %%
x = X_test.values
x_scaled_std = std_scaler.transform(x)
X_test_std = pd.DataFrame(x_scaled_std,columns=X_test.columns)

# %%
X_train_std.shape[1]
# Out:
# 30

# %% [markdown]
# # NN Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
def build_model():
  model1 = Sequential()
  model1.add(Dense(30, activation='relu', input_shape=(X_train.shape[1],)))
  model1.add(Dense(1, activation='linear'))
  return model1
model1 = build_model()

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                930
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 961
# Trainable params: 961
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model1.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.3, verbose=2,shuffle=False)
# Out:
# Epoch 1/100
# 4345/4345 - 16s - loss: 4126.3369 - mae: 6.4620 - val_loss: 447.7972 - val_mae: 18.8442 - 16s/epoch - 4ms/step
# Epoch 2/100
# 4345/4345 - 14s - loss: 322.8388 - mae: 7.3170 - val_loss: 2.9393 - val_mae: 0.8880 - 14s/epoch - 3ms/step
# Epoch 3/100
# 4345/4345 - 14s - loss: 358.7414 - mae: 7.1790 - val_loss: 113.6381 - val_mae: 9.3914 - 14s/epoch - 3ms/step
# Epoch 4/100
# 4345/4345 - 14s - loss: 364.2377 - mae: 5.7942 - val_loss: 0.2666 - val_mae: 0.3159 - 14s/epoch - 3ms/step
# Epoch 5/100
# 4345/4345 - 14s - loss: 501.2318 - mae: 4.8048 - val_loss: 53448.8750 - val_mae: 206.9358 - 14s/epoch - 3ms/step
# Epoch 6/100
# 4345/4345 - 16s - loss: 314.6635 - mae: 5.9735 - val_loss: 0.8734 - val_mae: 0.6577 - 16s/epoch - 4ms/step
# Epoch 7/100
# 4345/4345 - 16s - loss: 411.9367 - mae: 5.2164 - val_loss: 8.4359 - val_mae: 2.5081 - 16s/epoch - 4ms/step
# Epoch 8/100
# 4345/4345 - 14s - loss: 348.6043 - mae: 5.6607 - val_loss: 1.7207 - val_mae: 1.0209 - 14s/epoch - 3ms/step
# Epoch 9/100
# 4345/4345 - 16s - loss: 331.3499 - mae: 6.2682 - val_loss: 1.8830 - val_mae: 1.0405 - 16s/epoch - 4ms/step
# Epoch 10/100
# 4345/4345 - 15s - loss: 296.6117 - mae: 5.5007 - val_loss: 36.2506 - val_mae: 5.3330 - 15s/epoch - 4ms/step
# Epoch 11/100
# 4345/4345 - 14s - loss: 321.6992 - mae: 5.8258 - val_loss: 20.4821 - val_mae: 4.0328 - 14s/epoch - 3ms/step
# Epoch 12/100
# 4345/4345 - 14s - loss: 443.4673 - mae: 5.3254 - val_loss: 0.4928 - val_mae: 0.3930 - 14s/epoch - 3ms/step
# Epoch 13/100
# 4345/4345 - 16s - loss: 300.3881 - mae: 5.6158 - val_loss: 2.5622 - val_mae: 1.2454 - 16s/epoch - 4ms/step
# Epoch 14/100
# 4345/4345 - 16s - loss: 246.8042 - mae: 6.0258 - val_loss: 1017.0534 - val_mae: 28.5301 - 16s/epoch - 4ms/step
# Epoch 15/100
# 4345/4345 - 16s - loss: 313.0182 - mae: 5.5418 - val_loss: 0.5389 - val_mae: 0.5565 - 16s/epoch - 4ms/step
# Epoch 16/100
# 4345/4345 - 14s - loss: 310.9924 - mae: 5.7315 - val_loss: 7.0297 - val_mae: 2.3315 - 14s/epoch - 3ms/step
# Epoch 17/100
# 4345/4345 - 14s - loss: 265.5897 - mae: 5.5599 - val_loss: 0.5532 - val_mae: 0.5401 - 14s/epoch - 3ms/step
# Epoch 18/100
# 4345/4345 - 14s - loss: 244.5375 - mae: 5.6641 - val_loss: 1865.3604 - val_mae: 38.6295 - 14s/epoch - 3ms/step
# Epoch 19/100
# 4345/4345 - 14s - loss: 303.5099 - mae: 6.0173 - val_loss: 0.7442 - val_mae: 0.6173 - 14s/epoch - 3ms/step
# Epoch 20/100
# 4345/4345 - 14s - loss: 212.1298 - mae: 6.6471 - val_loss: 2476.6812 - val_mae: 44.5022 - 14s/epoch - 3ms/step
# Epoch 21/100
# 4345/4345 - 14s - loss: 399.8156 - mae: 6.3019 - val_loss: 0.6131 - val_mae: 0.5003 - 14s/epoch - 3ms/step
# Epoch 22/100
# 4345/4345 - 14s - loss: 214.9235 - mae: 4.9652 - val_loss: 3.9648 - val_mae: 1.7119 - 14s/epoch - 3ms/step
# Epoch 23/100
# 4345/4345 - 14s - loss: 220.3799 - mae: 4.4775 - val_loss: 57.7520 - val_mae: 6.8009 - 14s/epoch - 3ms/step
# Epoch 24/100
# 4345/4345 - 14s - loss: 310.2177 - mae: 4.8751 - val_loss: 1.1967 - val_mae: 0.9133 - 14s/epoch - 3ms/step
# Epoch 25/100
# 4345/4345 - 14s - loss: 422.1331 - mae: 4.8427 - val_loss: 1.3033 - val_mae: 0.5674 - 14s/epoch - 3ms/step
# Epoch 26/100
# 4345/4345 - 16s - loss: 388.0231 - mae: 4.4145 - val_loss: 0.2984 - val_mae: 0.3548 - 16s/epoch - 4ms/step
# Epoch 27/100
# 4345/4345 - 16s - loss: 227.1313 - mae: 4.1523 - val_loss: 18.5823 - val_mae: 3.8518 - 16s/epoch - 4ms/step
# Epoch 28/100
# 4345/4345 - 14s - loss: 315.1825 - mae: 5.0206 - val_loss: 1.9449 - val_mae: 1.1992 - 14s/epoch - 3ms/step
# Epoch 29/100
# 4345/4345 - 14s - loss: 234.2375 - mae: 4.8299 - val_loss: 0.4067 - val_mae: 0.4401 - 14s/epoch - 3ms/step
# Epoch 30/100
# 4345/4345 - 14s - loss: 253.0574 - mae: 3.9304 - val_loss: 4353.5054 - val_mae: 59.0868 - 14s/epoch - 3ms/step
# Epoch 31/100
# 4345/4345 - 16s - loss: 213.2126 - mae: 5.6952 - val_loss: 892.7607 - val_mae: 26.7374 - 16s/epoch - 4ms/step
# Epoch 32/100
# 4345/4345 - 14s - loss: 231.7299 - mae: 4.5865 - val_loss: 3.1457 - val_mae: 1.5656 - 14s/epoch - 3ms/step
# Epoch 33/100
# 4345/4345 - 14s - loss: 217.5936 - mae: 5.3173 - val_loss: 53.4471 - val_mae: 6.5251 - 14s/epoch - 3ms/step
# Epoch 34/100
# 4345/4345 - 15s - loss: 251.9684 - mae: 4.6218 - val_loss: 0.4632 - val_mae: 0.5240 - 15s/epoch - 4ms/step
# Epoch 35/100
# 4345/4345 - 14s - loss: 220.1730 - mae: 5.3227 - val_loss: 0.1116 - val_mae: 0.2168 - 14s/epoch - 3ms/step
# Epoch 36/100
# 4345/4345 - 14s - loss: 213.1774 - mae: 4.1987 - val_loss: 2.9414 - val_mae: 1.5123 - 14s/epoch - 3ms/step
# Epoch 37/100
# 4345/4345 - 15s - loss: 299.4326 - mae: 5.1409 - val_loss: 0.4605 - val_mae: 0.3404 - 15s/epoch - 4ms/step
# Epoch 38/100
# 4345/4345 - 15s - loss: 171.7111 - mae: 3.6092 - val_loss: 18.5951 - val_mae: 3.8471 - 15s/epoch - 4ms/step
# Epoch 39/100
# 4345/4345 - 16s - loss: 194.3060 - mae: 4.7501 - val_loss: 19.0748 - val_mae: 3.8750 - 16s/epoch - 4ms/step
# Epoch 40/100
# 4345/4345 - 14s - loss: 215.7081 - mae: 4.3938 - val_loss: 0.4674 - val_mae: 0.4847 - 14s/epoch - 3ms/step
# Epoch 41/100
# 4345/4345 - 14s - loss: 228.1376 - mae: 5.2661 - val_loss: 0.5011 - val_mae: 0.2708 - 14s/epoch - 3ms/step
# Epoch 42/100
# 4345/4345 - 16s - loss: 188.6004 - mae: 4.7331 - val_loss: 333.0722 - val_mae: 16.3071 - 16s/epoch - 4ms/step
# Epoch 43/100
# 4345/4345 - 14s - loss: 196.7843 - mae: 4.8486 - val_loss: 29.2643 - val_mae: 4.8301 - 14s/epoch - 3ms/step
# Epoch 44/100
# 4345/4345 - 16s - loss: 213.3016 - mae: 4.3648 - val_loss: 5055.2432 - val_mae: 63.5652 - 16s/epoch - 4ms/step
# Epoch 45/100
# 4345/4345 - 16s - loss: 184.6455 - mae: 4.5435 - val_loss: 4432.0430 - val_mae: 59.5506 - 16s/epoch - 4ms/step
# Epoch 46/100
# 4345/4345 - 14s - loss: 310.1313 - mae: 3.8859 - val_loss: 1.2488 - val_mae: 0.8095 - 14s/epoch - 3ms/step
# Epoch 47/100
# 4345/4345 - 14s - loss: 224.7302 - mae: 4.6781 - val_loss: 0.5373 - val_mae: 0.6018 - 14s/epoch - 3ms/step
# Epoch 48/100
# 4345/4345 - 16s - loss: 158.5941 - mae: 3.3421 - val_loss: 8.3601 - val_mae: 2.5695 - 16s/epoch - 4ms/step
# Epoch 49/100
# 4345/4345 - 14s - loss: 212.3428 - mae: 4.5562 - val_loss: 1300.0800 - val_mae: 32.2693 - 14s/epoch - 3ms/step
# Epoch 50/100
# 4345/4345 - 14s - loss: 190.5439 - mae: 5.9227 - val_loss: 0.2442 - val_mae: 0.3584 - 14s/epoch - 3ms/step
# Epoch 51/100
# 4345/4345 - 16s - loss: 206.3326 - mae: 3.4192 - val_loss: 139.0057 - val_mae: 10.5268 - 16s/epoch - 4ms/step
# Epoch 52/100
# 4345/4345 - 16s - loss: 174.4229 - mae: 5.0116 - val_loss: 177.4024 - val_mae: 11.9548 - 16s/epoch - 4ms/step
# Epoch 53/100
# 4345/4345 - 14s - loss: 164.2392 - mae: 4.4469 - val_loss: 0.3844 - val_mae: 0.5451 - 14s/epoch - 3ms/step
# Epoch 54/100
# 4345/4345 - 16s - loss: 197.3886 - mae: 4.3572 - val_loss: 11.5080 - val_mae: 3.0212 - 16s/epoch - 4ms/step
# Epoch 55/100
# 4345/4345 - 14s - loss: 239.6677 - mae: 3.5674 - val_loss: 1.4172 - val_mae: 1.0580 - 14s/epoch - 3ms/step
# Epoch 56/100
# 4345/4345 - 14s - loss: 171.7394 - mae: 4.5668 - val_loss: 0.4534 - val_mae: 0.5305 - 14s/epoch - 3ms/step
# Epoch 57/100
# 4345/4345 - 16s - loss: 145.7590 - mae: 4.3140 - val_loss: 0.2120 - val_mae: 0.3563 - 16s/epoch - 4ms/step
# Epoch 58/100
# 4345/4345 - 16s - loss: 134.5424 - mae: 3.6308 - val_loss: 5.4104 - val_mae: 2.0735 - 16s/epoch - 4ms/step
# Epoch 59/100
# 4345/4345 - 14s - loss: 289.1139 - mae: 4.3325 - val_loss: 5.6189 - val_mae: 2.0957 - 14s/epoch - 3ms/step
# Epoch 60/100
# 4345/4345 - 16s - loss: 190.7866 - mae: 3.3804 - val_loss: 8.6591 - val_mae: 2.6246 - 16s/epoch - 4ms/step
# Epoch 61/100
# 4345/4345 - 14s - loss: 151.0489 - mae: 3.5662 - val_loss: 0.1142 - val_mae: 0.1768 - 14s/epoch - 3ms/step
# Epoch 62/100
# 4345/4345 - 16s - loss: 143.8379 - mae: 4.0321 - val_loss: 0.1497 - val_mae: 0.2096 - 16s/epoch - 4ms/step
# Epoch 63/100
# 4345/4345 - 14s - loss: 164.8533 - mae: 4.2253 - val_loss: 0.2222 - val_mae: 0.3512 - 14s/epoch - 3ms/step
# Epoch 64/100
# 4345/4345 - 16s - loss: 173.5202 - mae: 3.4074 - val_loss: 0.5823 - val_mae: 0.6383 - 16s/epoch - 4ms/step
# Epoch 65/100
# 4345/4345 - 16s - loss: 145.2668 - mae: 3.9681 - val_loss: 11.2799 - val_mae: 2.9951 - 16s/epoch - 4ms/step
# Epoch 66/100
# 4345/4345 - 15s - loss: 161.3220 - mae: 3.6038 - val_loss: 0.0564 - val_mae: 0.1497 - 15s/epoch - 4ms/step
# Epoch 67/100
# 4345/4345 - 16s - loss: 117.8387 - mae: 4.5104 - val_loss: 2.0768 - val_mae: 1.2897 - 16s/epoch - 4ms/step
# Epoch 68/100
# 4345/4345 - 15s - loss: 188.4164 - mae: 3.4610 - val_loss: 0.0441 - val_mae: 0.1578 - 15s/epoch - 4ms/step
# Epoch 69/100
# 4345/4345 - 14s - loss: 163.3085 - mae: 3.2991 - val_loss: 326.8232 - val_mae: 16.1462 - 14s/epoch - 3ms/step
# Epoch 70/100
# 4345/4345 - 14s - loss: 216.8206 - mae: 4.1220 - val_loss: 0.2384 - val_mae: 0.4006 - 14s/epoch - 3ms/step
# Epoch 71/100
# 4345/4345 - 16s - loss: 95.2304 - mae: 3.2165 - val_loss: 3.1939 - val_mae: 1.5937 - 16s/epoch - 4ms/step
# Epoch 72/100
# 4345/4345 - 14s - loss: 137.9188 - mae: 3.1734 - val_loss: 295.3990 - val_mae: 15.3832 - 14s/epoch - 3ms/step
# Epoch 73/100
# 4345/4345 - 15s - loss: 179.4062 - mae: 4.2737 - val_loss: 0.1223 - val_mae: 0.2638 - 15s/epoch - 4ms/step
# Epoch 74/100
# 4345/4345 - 13s - loss: 109.3661 - mae: 3.1347 - val_loss: 2008.8506 - val_mae: 40.0877 - 13s/epoch - 3ms/step
# Epoch 75/100
# 4345/4345 - 13s - loss: 144.8999 - mae: 3.6975 - val_loss: 0.0648 - val_mae: 0.1823 - 13s/epoch - 3ms/step
# Epoch 76/100
# 4345/4345 - 13s - loss: 165.6648 - mae: 3.3660 - val_loss: 35.1124 - val_mae: 5.2855 - 13s/epoch - 3ms/step
# Epoch 77/100
# 4345/4345 - 15s - loss: 147.6457 - mae: 3.6023 - val_loss: 0.4445 - val_mae: 0.5759 - 15s/epoch - 4ms/step
# Epoch 78/100
# 4345/4345 - 15s - loss: 104.8285 - mae: 4.1641 - val_loss: 98.4412 - val_mae: 8.8627 - 15s/epoch - 4ms/step
# Epoch 79/100
# 4345/4345 - 14s - loss: 140.0963 - mae: 4.0160 - val_loss: 8.6208 - val_mae: 2.6164 - 14s/epoch - 3ms/step
# Epoch 80/100
# 4345/4345 - 14s - loss: 178.6300 - mae: 3.2714 - val_loss: 6405.4658 - val_mae: 70.8830 - 14s/epoch - 3ms/step
# Epoch 81/100
# 4345/4345 - 16s - loss: 84.1188 - mae: 3.1959 - val_loss: 478.8484 - val_mae: 19.5944 - 16s/epoch - 4ms/step
# Epoch 82/100
# 4345/4345 - 14s - loss: 161.2941 - mae: 4.1925 - val_loss: 0.0547 - val_mae: 0.1644 - 14s/epoch - 3ms/step
# Epoch 83/100
# 4345/4345 - 14s - loss: 117.6837 - mae: 3.7714 - val_loss: 4.6468 - val_mae: 1.9108 - 14s/epoch - 3ms/step
# Epoch 84/100
# 4345/4345 - 16s - loss: 105.4070 - mae: 3.6562 - val_loss: 3982.9966 - val_mae: 56.4363 - 16s/epoch - 4ms/step
# Epoch 85/100
# 4345/4345 - 14s - loss: 154.9062 - mae: 3.7706 - val_loss: 4.9227 - val_mae: 1.9795 - 14s/epoch - 3ms/step
# Epoch 86/100
# 4345/4345 - 14s - loss: 162.9319 - mae: 3.1037 - val_loss: 0.1277 - val_mae: 0.2886 - 14s/epoch - 3ms/step
# Epoch 87/100
# 4345/4345 - 14s - loss: 181.0347 - mae: 3.3495 - val_loss: 5.8176 - val_mae: 2.1411 - 14s/epoch - 3ms/step
# Epoch 88/100
# 4345/4345 - 14s - loss: 139.2275 - mae: 3.0582 - val_loss: 0.6106 - val_mae: 0.6814 - 14s/epoch - 3ms/step
# Epoch 89/100
# 4345/4345 - 14s - loss: 156.6074 - mae: 3.7297 - val_loss: 1.8907 - val_mae: 1.1948 - 14s/epoch - 3ms/step
# Epoch 90/100
# 4345/4345 - 14s - loss: 114.3028 - mae: 3.7116 - val_loss: 598.1926 - val_mae: 21.8581 - 14s/epoch - 3ms/step
# Epoch 91/100
# 4345/4345 - 16s - loss: 108.7280 - mae: 3.8855 - val_loss: 0.2771 - val_mae: 0.4488 - 16s/epoch - 4ms/step
# Epoch 92/100
# 4345/4345 - 14s - loss: 132.5504 - mae: 4.3173 - val_loss: 0.1463 - val_mae: 0.2941 - 14s/epoch - 3ms/step
# Epoch 93/100
# 4345/4345 - 14s - loss: 85.7223 - mae: 3.4372 - val_loss: 0.1440 - val_mae: 0.3049 - 14s/epoch - 3ms/step
# Epoch 94/100
# 4345/4345 - 15s - loss: 100.5802 - mae: 3.6997 - val_loss: 167.3232 - val_mae: 11.5515 - 15s/epoch - 4ms/step
# Epoch 95/100
# 4345/4345 - 14s - loss: 117.4012 - mae: 3.2382 - val_loss: 746.5402 - val_mae: 24.4192 - 14s/epoch - 3ms/step
# Epoch 96/100
# 4345/4345 - 14s - loss: 112.8147 - mae: 4.2591 - val_loss: 0.1543 - val_mae: 0.3134 - 14s/epoch - 3ms/step
# Epoch 97/100
# 4345/4345 - 16s - loss: 117.7242 - mae: 3.2735 - val_loss: 0.2133 - val_mae: 0.3879 - 16s/epoch - 4ms/step
# Epoch 98/100
# 4345/4345 - 14s - loss: 114.4182 - mae: 3.8544 - val_loss: 0.0619 - val_mae: 0.1410 - 14s/epoch - 3ms/step
# Epoch 99/100
# 4345/4345 - 16s - loss: 142.7726 - mae: 2.8812 - val_loss: 0.2319 - val_mae: 0.3618 - 16s/epoch - 4ms/step
# Epoch 100/100
# 4345/4345 - 14s - loss: 139.5405 - mae: 3.1176 - val_loss: 3071.9941 - val_mae: 49.5609 - 14s/epoch - 3ms/step

# %%
loss, acc = model1.evaluate(X_test, Y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 49.637

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
